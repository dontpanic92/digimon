# %%
from PIL import Image
from multiprocessing import Pool

import os

LOAD_RAW_FOLDER = "crawlers/images/full/"
SAVE_4K_FOLDER = "./data/4k/"
SAVE_1080_FOLDER = "./data/1080/"
SAVE_540_FOLDER = "./data/540/"
SAVE_270_FOLDER = "./data/270/"
os.makedirs(SAVE_4K_FOLDER, exist_ok=True)
os.makedirs(SAVE_1080_FOLDER, exist_ok=True)
os.makedirs(SAVE_540_FOLDER, exist_ok=True)
os.makedirs(SAVE_270_FOLDER, exist_ok=True)

skip_existing = True

# %%
def f_4k(f):
    save_path = os.path.join(SAVE_4K_FOLDER, f)
    if skip_existing and os.path.exists(save_path):
        return

    im = Image.open(os.path.join(LOAD_RAW_FOLDER, f))
    width, height = im.size

    target_width = 3840
    target_height = 2160
    im1 = None
    im2 = None
    if width > target_width:
        left = (width - target_width) / 2
        im1 = im.crop((left, 0, width - left, height))
    elif target_width > width:
        left = (target_width - width) / 2
        im1 = Image.new(im.mode, (target_width, height), (0, 0, 0))
        im1.paste(im, (left, 0))
    else:
        im1 = im

    if height > target_height:
        top = (height - target_height) / 2
        im2 = im1.crop((0, top, target_width, height - top))
    elif target_height > height:
        top = (target_height - height) / 2
        im2 = Image.new(im1.mode, (target_width, target_height), (0, 0, 0))
        im2.paste(im1, (0, top))
    else:
        im2 = im1

    im2.save(save_path)
    
with Pool(6) as p:
    p.map(f_4k, os.listdir(LOAD_RAW_FOLDER))
# Out:
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (150969345 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (168510160 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (132710400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (120744088 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (105525420 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (136599752 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (150969345 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (103119660 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (146660000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (93135501 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (132710400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (132710400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (120744088 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (120744088 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (125759718 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (120744088 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (94072800 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (93071827 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (92807691 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (126570000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (120744088 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (131058408 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (105729800 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (150969345 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (94045928 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (92160000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (98687500 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (90591255 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (144016000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (98476344 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (157071524 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (132710400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (132710400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (176567622 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (123808955 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (160700813 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (156303126 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (139402080 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (100454464 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (120777360 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (92000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (134231552 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (144143035 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (98902783 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (104676439 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (159180000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (137473998 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (120744088 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (128563472 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (152686080 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (156364600 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (132710400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (178254648 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (150969345 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (150969345 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (121500000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (126570000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (93796560 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (109441860 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (136599752 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/PIL/Image.py:2847: DecompressionBombWarning: Image size (96874176 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
def f_1080(f):
    if f.startswith('.'):
        return
    save_path = os.path.join(SAVE_1080_FOLDER, f)
    if skip_existing and os.path.exists(save_path):
        return

    im = Image.open(os.path.join(SAVE_4K_FOLDER, f))
    target_size = (1920, 1080)
    im = im.resize(target_size)
    im.save(save_path, "PNG")

with Pool(6) as p:
    p.map(f_1080, os.listdir(SAVE_4K_FOLDER))

# %%
def f_540(f):
    if f.startswith('.'):
        return
    save_path = os.path.join(SAVE_540_FOLDER, f)
    if skip_existing and os.path.exists(save_path):
        return

    im = Image.open(os.path.join(SAVE_4K_FOLDER, f))
    target_size = (960, 540)
    im = im.resize(target_size)
    im.save(save_path, "PNG")

with Pool(6) as p:
    p.map(f_540, os.listdir(SAVE_4K_FOLDER))

# %%
"""def fix_1080(f):
    if f.startswith('.'):
        return
    try:
        save_path = os.path.join(SAVE_4K_FOLDER, f)
        im = Image.open(save_path)
    except Exception as e:
        print(e)

with Pool(6) as p:
    p.map(fix_1080, os.listdir(SAVE_4"""K_FOLDER))

# %%
def f_270(f):
    if f.startswith('.'):
        return

    save_path = os.path.join(SAVE_270_FOLDER, f)
    if skip_existing and os.path.exists(save_path):
        return

    im = Image.open(os.path.join(SAVE_4K_FOLDER, f))
    target_size = (480, 270)
    im = im.resize(target_size)
    im.save(save_path, "PNG")


with Pool(6) as p:
    p.map(f_270, os.listdir(SAVE_4K_FOLDER))
